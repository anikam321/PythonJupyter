# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Dec 15 20:13:39 2021

@author: brand
"""
#Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from os.path import dirname, join as pjoin

#Set the save folder to the current path of this Python file
#path = os.path.abspath(__file__) # Python program file
#folder_path = pjoin(dirname(path)) # Current directory
#os.chdir(folder_path)


#Read Table A17 values
data = pd.read_excel (r'Room_106.xlsx', sheet_name=('DATA'), dtype = str)
#imports data from excel file
data.to_csv('Room_106.txt')
#saves data in a csv file
data = np.loadtxt('Room_106.txt', dtype = str, delimiter = ',', skiprows=1)
#data = open('Room_106.txt', errors = "ignore")


# In[]
length = len(data)
time = 5*np.arange(0,length,1)

y = np.array([float(data[ii,4]) for ii in range(length)])
my_xticks = [data[ii,3] for ii in range(length)]

plt.figure(figsize = (8,6));
plt.plot(time,y)
plt.title("Rm 106 Carbon Dioxide vs Time", fontsize = 20)
plt.xlabel('Time [min]', fontsize = 16)
plt.ylabel('Temperature [°F]', fontsize = 16)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.savefig('Anika_Mitra_Final.png')
